# %%
from PIL import Image

# %%
Image.open("comp.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
amc = Image.open("comp.jpeg")

# %%
cropmac = amc.crop((796.5,800,1196.5,1257))

# %%
cropmac
# Out:
# <PIL.Image.Image image mode=RGB size=400x457>

# %%
amc.paste(im=cropmac,box=(0,0))

# %%
amc
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
amc.paste(im=cropmac,box=(700,0))

# %%
amc
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
amc
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1993x1257>

# %%
Image.open("redhg.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
Image.open("bluehg.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>

# %%
b = Image.open("bluehg.jpeg")

# %%
r = Image.open("redhg.jpeg")

# %%
r.putalpha(128)

# %%
r
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
b.putalpha(200)

# %%
b
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
b.paste(r,box=(0,0),mask=r)

# %%
b
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=200x200>

# %%
b.save("purple.png")

# %%
Image.open("purple.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x200>
